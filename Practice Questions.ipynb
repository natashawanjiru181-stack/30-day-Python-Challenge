# %%
#Day 1
#Basics: Printing & Operators
#1
#Print Hello World!
print('Hello World!')

#blank line
print()

#Addition
print(7+3)

#Subtraction
print(7-3)

#Multiplication
print(7*3)

#Division
print(7/3)

#Floor Division - type of division that always rounds the result down to the nearest whole number
print(7//3)

#Modulus- remainder after division
print(7%3)

#Exponential - power
print(7**3)
# Out:
# Hello World!
#
# 10
# 4
# 21
# 2.3333333333333335
# 2
# 1
# 343

# %%
#2
a=11
b=4
#Perform arithmetic operations
print(a+b, a-b, a*b, a/b, a%b, a**b)# ordered
# Out:
# 15 7 44 2.75 3 14641

# %%
#3
print(3/2)
print(3//2)
print(-3//2)
print(-3/2)
# Out:
# 1.5
# 1
# -2
# -1.5

# %%
# Data Type Identification (type())
#1
a=12
print(type(a))
# Out:
# <class 'int'>

# %%
b=12.2
print(type(b))
# Out:
# <class 'float'>

# %%
c=12+3j
print(type(c))
# Out:
# <class 'complex'>

# %%
d='Introduction'
print(type(d))
# Out:
# <class 'str'>

# %%
e=['Chinese I','Chinese II']#box brackets
print(type(e))
# Out:
# <class 'list'>

# %%
f={'Chinese 1':'CHI1000A','Chinese II':'CHI1001A'}#curly brackets only
print(type(f))
# Out:
# <class 'dict'>

# %%
g={34, 45, 67, 98}#difference with dict doesnt have key value pairs
print(type(g))
# Out:
# <class 'set'>

# %%
#2
#print the type
print(type(10))
print(type(10.0))
print(type(10.))
print(type(10j))
print(type('10'))
print(type("[1, 2, 3]"))
print(type([1, '2', 3.0]))
print(type({'a': 1}))
print(type({1, 2, 2, 3}))
print(type(()))
print(type((1)))
print(type((1,)))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'float'>
# <class 'complex'>
# <class 'str'>
# <class 'str'>
# <class 'list'>
# <class 'dict'>
# <class 'set'>
# <class 'tuple'>
# <class 'int'>
# <class 'tuple'>

# %%
#3
#Create a variable that looks like a list but is actually a string
#For it to work the values must be numerical
a='[1, 2, 3, 4]'
print(type(a))

#Proof
b='[1, 'Crazy', 'Lady', 4]'
print(type(b))
# Out:
#   Cell In[3], line 7
#     b='[1, 'Crazy', 'Lady', 4]'
#             ^
# SyntaxError: invalid syntax

# %%
#Sets, Tuples, Lists, Dicts
#1
#Create a set with values 
# Confirm by printing its type. 
# Then add one more float and print the set.
#Why is this not called a float?
a={9.8, 3.14, 2.7}
print(type(a))

a={9.8, 3.14, 2.7, 3.8}
print(a)
# Out:
# <class 'set'>
# {3.14, 9.8, 2.7, 3.8}

# %%
#2
#Create a list, tuple and set of same 5 values
#Print all three objects and then print their types.
# Ensure at least one value is duplicated- 'Introduction to Programming'
# observe the difference in outputs.

#list - duplicate is seen in output
a=['Introduction to Programming', 'Introduction to Programming', 'Introduction to Information Technology', 'Database Systems', 'Probability and Statistics I']

#tuple - duplicate is seen in output
b=('Introduction to Programming', 'Introduction to Programming', 'Introduction to Information Technology', 'Database Systems', 'Probability and Statistics I')

#set - no duplicate is seen in output
c={'Introduction to Programming', 'Introduction to Programming', 'Introduction to Information Technology', 'Database Systems', 'Probability and Statistics I'}

print(a)
print(b)
print(c)

print(type(a))
print(type(b))
print(type(c))
# Out:
# ['Introduction to Programming', 'Introduction to Programming', 'Introduction to Information Technology', 'Database Systems', 'Probability and Statistics I']
# ('Introduction to Programming', 'Introduction to Programming', 'Introduction to Information Technology', 'Database Systems', 'Probability and Statistics I')
# {'Introduction to Programming', 'Probability and Statistics I', 'Database Systems', 'Introduction to Information Technology'}
# <class 'list'>
# <class 'tuple'>
# <class 'set'>

# %%
#3 Create a dictionary with exactly the keys name, country, city. Assign any values. Print the dictionary and its type.
# For a dict, its curved brackets then curly brackets
# Each key and value should be in its own quotes
a=({'country':'Kenya','city':'Mombasa'})
print(a)
print(type(a))
# Out:
# {'city:Mombasa', 'country:Kenya'}
# <class 'set'>

# %%
#4 Create a one-element tuple and a one-element set, each containing the string "Python". Print both and their types.
a=('Python')
print(a)
print(type(a))

b={'Python'}
print(b)

print(type(b))
# Out:
# Python
# <class 'str'>
# {'Python'}
# <class 'set'>

# %%
#5.	Create a set from a list that contains duplicates and print the set to show duplicate removal.
a=set(['Code', 'Daily', 'Grants', 'Freedom', 'Code', 'Daily'])
print(a)# Output has no duplicates
# Out:
# {'Grants', 'Code', 'Daily', 'Freedom'}

# %%
#4 Arithmetic & Edge Cases
#1.	Using two integers a and b of your choice, print:	a % b	b % a
#Explain in printed text the difference in the results if any (as part of your print output).
a=45
b=76
print(a % b)
print(b % a)
# Out:
# 45
# 31

# %% [markdown]
# # Explanation of operation above
# print(a % b) shows 45 because 76 cannot divide 45 hence in the operation leaves a remainder of 45 for.<br>print(b % a) 45 can divide 76 once leaving a remainder of 31

# %%
#1.	Demonstrate the difference between ** and * by calculating 2**3 and 2*3. Print them with clear labels.
#Method A
print(f'Exponential: {2**3}')
print(f'Multiplication: {2*3}')

#Method B
a='Exponential:'
b= 2**3
print(a,b)
# Out:
# Exponential: 8
# Multiplication: 6
# Exponential: 8

# %%
#2.	Using only arithmetic operators, print the value of:
#	((5 + 3) * 2) ** 2 // 7 % 5
#Also print the intermediate results after each operator step (each step on a new line).

#Step 1
a=(5+3)*2
print(a)

#Step 2
b=a**2
print(b)

#Step 3
c=b//7%5

# Final answer
print(c)
# Out:
# 16
# 256
# 1

# %%
#5 String & Printing 
#1.	Create a string variable containing your first and last name separated by a space.
a='Natasha Gicheha'
print(a) #Print:The original string

print(len(a)) #The number of characters in the string (using len() 
print(a[:1]) #The first character 
print(a[14:]) #The last character - ignores the character in index 14 and looks at index 15

print(a[1:])
# Out:
# Natasha Gicheha
# 15
# N
# a
# atasha Gicheha

# %%
#1.	Print the string "Asabeneh" three times on one line separated by a single space, using a single print() without typing the word three times
print('Asabeneh ' * 3)
# Out:
# Asabeneh Asabeneh Asabeneh

# %%
#Using not operator with variables to negate their values
available=True
print(not available)
# Out:
# False

# %%
#True false statements has to start with a capital letter
#Proof
print(not true)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 3
#       1 #True false statements has to start with a capital letter
#       2 #Proof
# ----> 3 print(not true)
#       5 #Correct version
#       6 print(not True)
#
# NameError: name 'true' is not defined

# %%
#Correct version
print(not True)
# Out:
# False
